# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = 'C:\\Users\\Rubio\\AppData\\Roaming\\SPB_16.6'

# %%
f_app = os.path.join(dir_data, 'HomeCredit_columns_description.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: C:\Users\Rubio\AppData\Roaming\SPB_16.6\HomeCredit_columns_description.csv

# %%
# data 資訊
app_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
# Unnamed: 0     205 non-null int64
# Table          205 non-null object
# Row            205 non-null object
# Description    205 non-null object
# Special        80 non-null object
# Unnamed: 5     1 non-null object
# Unnamed: 6     1 non-null object
# dtypes: int64(1), object(6)
# memory usage: 11.3+ KB

# %%
# data 資訊(只有第一蘭可計算)
app_train.describe()
# Out:
#        Unnamed: 0
# count  205.000000
# mean   105.458537
# std     60.206462
# min      1.000000
# 25%     54.000000
# 50%    105.000000
# 75%    156.000000
# max    221.000000

# %%
# 取前 15 筆
app_train.head(15)
# Out:
#     Unnamed: 0                         Table                  Row  \
# 0            1  application_{train|test}.csv           SK_ID_CURR
# 1            2  application_{train|test}.csv               TARGET
# 2            5  application_{train|test}.csv   NAME_CONTRACT_TYPE
# 3            6  application_{train|test}.csv          CODE_GENDER
# 4            7  application_{train|test}.csv         FLAG_OWN_CAR
# 5            8  application_{train|test}.csv      FLAG_OWN_REALTY
# 6            9  application_{train|test}.csv         CNT_CHILDREN
# 7           10  application_{train|test}.csv     AMT_INCOME_TOTAL
# 8           11  application_{train|test}.csv           AMT_CREDIT
# 9           12  application_{train|test}.csv          AMT_ANNUITY
# 10          13  application_{train|test}.csv      AMT_GOODS_PRICE
# 11          14  application_{train|test}.csv      NAME_TYPE_SUITE
# 12          15  application_{train|test}.csv     NAME_INCOME_TYPE
# ...

# %%
# 計算 row , column
row_counter, column_counter = app_train.shape
print("The row's and column's numbers are (%d , %d)" % (row_counter, column_counter))
# Out:
# The row's and column's numbers are (205 , 7)

# %%
# 列出所有欄位
display(app_train)
# Out:
#      Unnamed: 0                         Table                    Row  \
# 0             1  application_{train|test}.csv             SK_ID_CURR
# 1             2  application_{train|test}.csv                 TARGET
# 2             5  application_{train|test}.csv     NAME_CONTRACT_TYPE
# 3             6  application_{train|test}.csv            CODE_GENDER
# 4             7  application_{train|test}.csv           FLAG_OWN_CAR
# ..          ...                           ...                    ...
# 200         217     installments_payments.csv  NUM_INSTALMENT_NUMBER
# 201         218     installments_payments.csv        DAYS_INSTALMENT
# 202         219     installments_payments.csv     DAYS_ENTRY_PAYMENT
# 203         220     installments_payments.csv         AMT_INSTALMENT
# 204         221     installments_payments.csv            AMT_PAYMENT
#
#                                            Description  \
# 0                             ID of loan in our sample
# ...

# %%
# 截取部分資料 1
app_train[5:10][['Table','Row']]
# Out:
#                           Table               Row
# 5  application_{train|test}.csv   FLAG_OWN_REALTY
# 6  application_{train|test}.csv      CNT_CHILDREN
# 7  application_{train|test}.csv  AMT_INCOME_TOTAL
# 8  application_{train|test}.csv        AMT_CREDIT
# 9  application_{train|test}.csv       AMT_ANNUITY

# %%
# 截取部分資料 2
app_train.loc[0:5]
# Out:
#    Unnamed: 0                         Table                 Row  \
# 0           1  application_{train|test}.csv          SK_ID_CURR
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
# 5           8  application_{train|test}.csv     FLAG_OWN_REALTY
#
#                                          Description Special Unnamed: 5  \
# 0                           ID of loan in our sample     NaN        NaN
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# 2        Identification if loan is cash or revolving     NaN        NaN
# 3                               Gender of the client     NaN        NaN
# 4                      Flag if the client owns a car     NaN        NaN
# 5                Flag if client owns a house or flat     NaN        NaN
#
# ...

# %%
# 截取部分資料 3
app_train.iloc[10:20][['Description']]
# Out:
#                                           Description
# 10  For consumer loans it is the price of the good...
# 11  Who was accompanying client when he was applyi...
# 12  Clients income type (businessman, working, mat...
# 13     Level of highest education the client achieved
# 14                        Family status of the client
# 15  What is the housing situation of the client (r...
# 16  Normalized population of region where client l...
# 17    Client's age in days at the time of application
# 18  How many days before the application the perso...
# 19  How many days before the application did clien...

# %%
# 取得欄位名稱
app_train.columns
# Out:
# Index(['Unnamed: 0', 'Table', 'Row', 'Description', 'Special', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
# 列印無欄位名稱數據
app_train.head()[['Unnamed: 0']]
# Out:
#    Unnamed: 0
# 0           1
# 1           2
# 2           5
# 3           6
# 4           7
